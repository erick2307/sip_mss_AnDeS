# %%
import numpy as np
import stumpy
from datetime import datetime, timedelta
from icecream import ic
from tqdm import tqdm
import arrow
from dateutil import tz
import geopandas as gpd
import glob
import matplotlib.pyplot as plt

timezone = tz.gettz("Asia/Tokyo")

# %%
def read_database(start=2016, stop=2024):
    db = {}
    for year in tqdm(np.arange(start, stop + 1, 1), desc="Reading database"):
        y = np.load(f"data/ntt_mss_{year}.npy")
        mids = np.load(f"data/ntt_mss_{year}_areas.npy")
        db[year] = (y, mids)
    return db

# %%
def join_database_of_meshcode(db, meshcode):
    for key in db.keys():
        meshids = db[key][1]
        try:
            pos = np.where(meshids == meshcode)[0].item()
        except:
            print(f"Meshcode {meshcode} not found in {key}")
            return None
        if key == 2016:
            data = db[key][0][:,pos]
        else:
            data = np.concatenate((data, db[key][0][:,pos]), axis=0)
    return data

# %%
def set_vars(cur):
    target_year = cur.year
    target_month = cur.month
    target_day = cur.day
    target_hour = cur.hour
    return target_year, target_month, target_day, target_hour

# %%
def get_date_one_month_ago(target_year, target_month, target_day, target_hour):
    to_date = arrow.get(target_year, target_month, target_day, target_hour)
    last_month = to_date.shift(months=-1)
    return last_month.datetime

# %%
def end_of_year_bool(year1,year2):
    if year1 != year2:
        return True
    else:
        return False

# %%
def get_hours(start_year, start_month, start_day, start_hour, stop_year, stop_month, stop_day, stop_hour):
    start = datetime(start_year, start_month, start_day, start_hour, 0, 0, 0, tzinfo=timezone)
    stop = datetime(stop_year, stop_month, stop_day, stop_hour, 0, 0, 0, tzinfo=timezone)
    delta = stop - start
    return delta.days * 24 + delta.seconds // 3600


def get_dateindex(dt, num_days):
    index = sum(num_days[:dt.year-2016]) + get_hours(dt.year,1,1,0,dt.year,dt.month,dt.day,dt.hour)
    return index


def get_history_data(data, num_days, cur, last_month, eoy_bool, alpha=0):
    if eoy_bool:
        alpha = 1
    for i, year in enumerate(np.arange(2016, last_month.year)):
        start_index = get_dateindex(datetime(year,last_month.month,last_month.day,last_month.hour,0,0,0,timezone), num_days)
        stop_index = get_dateindex(datetime(year+alpha,cur.month,cur.day,cur.hour,0,0,0,timezone), num_days)
        if i == 0:    
            history_data = data[start_index:stop_index]
        else:
            history_data = np.concatenate((history_data, data[start_index:stop_index]), axis=0)
    return history_data

# %%
def andes(data, num_days, cur, stream_point, meshcode):    
    target_year, target_month, target_day, target_hour = set_vars(cur)
    last_month = get_date_one_month_ago(target_year, target_month, target_day, target_hour)
    eoy_bool = end_of_year_bool(target_year, last_month.year)
    history_data = get_history_data(data, num_days, cur, last_month, eoy_bool)
    # convert data to float64 and replace -1 with np.nan
    history_data = np.where(history_data == -1, np.nan, history_data).astype(np.float64)
    stream_point = np.where(stream_point == -1, np.nan, stream_point).astype(np.float64)
    # calculate the left matrix profile
    T = history_data
    m = 3
    stream = stumpy.stumpi(T, m, normalize=False, egress=False)
    # update stream with new data
    stream.update(stream_point)
    # calculate the left MP
    a = stream._left_P[m:]
    # filter initial 'inf' values
    af = a[np.isfinite(a)]
    # calculate std of the left MP ==> Condition for anomaly detection
    return stream._left_P[-1] > (af.mean() + 4 * af.std())

# %% [markdown]
# ## Load Database

# %%
# YOU MAY RUN THIS ONCE TO LOAD THE DATABASE
db = read_database(start=2016, stop=2024)
# Out:
# Reading database: 100%|██████████| 9/9 [01:51<00:00, 12.40s/it]

# %% [markdown]
# # RUN FROM HERE

# %%
pref = 45
cur = datetime(2024,8,8,16,0,0,0,timezone) # Hyuga-nada EQ

path = glob.glob(f'/Volumes/Pegasus32/japan/mesh/mesh4/fixedmesh4_*{pref}*.geojson')[0]
mesh = gpd.read_file(path, driver='GeoJSON')
tsunami = gpd.read_file(f'/Volumes/Pegasus32/japan/tsunami/tsunami/{pref}.geojson', driver='GeoJSON')
tsunami_mesh = gpd.sjoin(mesh, tsunami)
# Out:
# /Users/erick/Documents/GitHub/sip_mss_AnDeS/.conda/lib/python3.11/site-packages/pyogrio/raw.py:196: RuntimeWarning: driver GeoJSON does not support open option DRIVER
#   return ogr_read(
# /Users/erick/Documents/GitHub/sip_mss_AnDeS/.conda/lib/python3.11/site-packages/pyogrio/raw.py:196: RuntimeWarning: driver GeoJSON does not support open option DRIVER
#   return ogr_read(

# %% [markdown]
# ### Algorithm 2 - Multiple point data

# %%
tsunami_mesh['MESH4_ID'] = tsunami_mesh['MESH4_ID'].astype(int)
meshcodes = tsunami_mesh['MESH4_ID'].values[:5]
for meshcode in meshcodes:
    data = join_database_of_meshcode(db, meshcode)
    num_days = [db[key][0].shape[0] for key in db.keys()]
    xhours = 1 * 24
    dates_before = [cur - timedelta(hours=i) for i in range(xhours,0,-1)]
    dates_after = [cur + timedelta(hours=i) for i in range(xhours)]
    dates = dates_before + dates_after
    img = []
    for date in dates:
        # this is input data
        cur_index = get_dateindex(date, num_days)
        stream_point = data[cur_index]
        # online anomaly detection
        anomaly = andes(data, num_days, date, stream_point, meshcode)
        img.append(anomaly)
        if anomaly:
            ic(date)
    arr = np.array(img).astype(int)
    # add to arr cur.hours points of np.nan at the beginning
    arr = np.concatenate((np.full(dates[0].hour, np.nan), arr))
    arr = np.concatenate((arr,np.full((23 - dates[-1].hour), np.nan)))


    plt.imshow(arr.reshape(-1,24), cmap='nipy_spectral_r')
    days = set([dates[i].date() for i in range(len(dates))])
    # set up y ticks labels
    plt.yticks(np.arange(0,len(days)), [f"{i}" for i in sorted(days)])
    plt.xticks(np.arange(0,24), [f"{i:02d}" for i in np.arange(0,24)], rotation=45);
    # create vertical lines at 0.5 of each hour
    for i in range(1,24):
        plt.axvline(i-0.5, color='black', linewidth=0.3)
    # create horizontal lines at 0.5 of each hour
    for i in range(1,len(days)):
        plt.hlines(i-0.5, xmin=-0.5,xmax=23.5,color='black', linewidth=0.3)
    plt.xlabel("Hour Frame of the day (e.g. 08 means 08:00 to 08:59)")
    plt.savefig(f"{meshcode}.png", dpi=300)
# Out:
# ic| date: datetime.datetime(2024, 8, 7, 16, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 17, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 18, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 19, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 20, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 21, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 22, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 23, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 0, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 1, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 2, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 3, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 4, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 5, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 6, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 7, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 8, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 9, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 10, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 11, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 12, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 13, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 14, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 15, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 16, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 17, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 18, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 19, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 20, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 21, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 22, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 23, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 0, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 1, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 2, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 3, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 4, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 5, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 6, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 7, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 8, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 9, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 10, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 11, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 12, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 13, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 14, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 15, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 16, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 17, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 18, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 20, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 21, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 22, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 23, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 0, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 1, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 2, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 3, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 4, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 5, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 6, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 7, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 8, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 9, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 10, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 11, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 12, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 13, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 14, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 15, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 16, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 17, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 18, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 19, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 20, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 21, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 22, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 23, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 0, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 1, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 2, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 3, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 4, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 5, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 6, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 7, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 8, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 9, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 10, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 11, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 12, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 13, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 14, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 15, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 16, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 17, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 18, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 19, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 20, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 21, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 22, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 23, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 0, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 1, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 2, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 3, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 4, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 5, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 6, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 8, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 9, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 10, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 11, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 12, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 13, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 14, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 15, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 16, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 17, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 18, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 19, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 20, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 21, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 22, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 23, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 0, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 1, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 2, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 3, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 4, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 5, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 6, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 7, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 8, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 9, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 10, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 11, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 12, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 13, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 14, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 15, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 16, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 17, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 18, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 19, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 20, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 21, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 22, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 23, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 0, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 1, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 2, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 3, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 4, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 5, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 6, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 8, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 9, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 10, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 11, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 12, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 13, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 14, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 15, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 16, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 17, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 18, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 19, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 20, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 21, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 22, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 23, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 0, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 1, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 2, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 3, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 4, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 5, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 6, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 7, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 8, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 9, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 10, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 11, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 12, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 13, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 14, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 15, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 16, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 17, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 18, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 19, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 20, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 21, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 22, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 7, 23, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 0, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 1, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 2, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 3, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 4, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 5, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 6, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 7, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 8, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 9, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 10, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 11, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 12, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 13, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 14, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 15, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 16, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 17, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 18, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 19, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 20, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 21, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 22, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 8, 23, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 0, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 1, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 2, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 3, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 4, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 5, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 6, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 7, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 8, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 9, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 10, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 11, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 12, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 13, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 14, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
# ic| date: datetime.datetime(2024, 8, 9, 15, 0, tzinfo=tzfile('/usr/share/zoneinfo/Asia/Tokyo'))
